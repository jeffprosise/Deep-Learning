# %% [markdown]
# # Multiclass classification with neural networks
#
# Neural networks are adept at fitting non-linear datasets. To demonstrate, we'll fit a multiclass classifier to a four-class dataset generated with Scikit's [make_blobs](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html) function. Start by creating the dataset and plotting it. In the plot, purple corresponds to class 0, light blue corresponds to class 1, taupe corresponds to class 2, and red corresponds to class 3.

# %%
import numpy as np
from sklearn.datasets import make_blobs
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# %matplotlib inline

x, y = make_blobs(n_samples=200, centers=4, n_features=2, cluster_std=0.8, random_state=0)
x = MinMaxScaler().fit_transform(x)

plt.figure(figsize=(12, 8))
plt.axes().set_aspect('equal')
plt.scatter(x[:, 0], x[:, 1], c=y, s=300, cmap=plt.cm.get_cmap('rainbow', 4), alpha=0.5)
plt.colorbar(ticks=range(4))
plt.clim(-0.5, 3.5)

# %% [markdown]
# Define a simple neural network (a multilayer perceptron) with a single hidden layer. Since this network is intended to perform multiclass classification, include an output layer that contains four neurons (one per class) and uses the [softmax](https://keras.io/api/layers/activations/#softmax-function) activation function, and specify [categorical_crossentropy](https://keras.io/api/losses/probabilistic_losses/#categorical_crossentropy-function) as the loss function.

# %%
from keras.models import Sequential
from keras.layers import Dense
 
model = Sequential()
model.add(Dense(128, activation='relu', input_dim=2))
model.add(Dense(4, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               384
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 900
# Trainable params: 900
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Use the [to_categorical](https://keras.io/api/utils/python_utils/#to_categorical-function) function to one-hot-encode the class labels. Then train the network. Use a small batch size since there are only 200 samples in the dataset..

# %%
from tensorflow.keras.utils import to_categorical

y_cat = to_categorical(y)
hist = model.fit(x, y_cat, validation_split=0.2, epochs=40, batch_size=10)
# Out:
# Epoch 1/40
# 16/16 [==============================] - 7s 23ms/step - loss: 1.4288 - accuracy: 0.0554 - val_loss: 1.3785 - val_accuracy: 0.2500
# Epoch 2/40
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3669 - accuracy: 0.3521 - val_loss: 1.3350 - val_accuracy: 0.6250
# Epoch 3/40
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3147 - accuracy: 0.6307 - val_loss: 1.2964 - val_accuracy: 0.5500
# Epoch 4/40
# 16/16 [==============================] - 0s 1ms/step - loss: 1.2743 - accuracy: 0.6183 - val_loss: 1.2599 - val_accuracy: 0.5750
# Epoch 5/40
# 16/16 [==============================] - 0s 1ms/step - loss: 1.2497 - accuracy: 0.6449 - val_loss: 1.2236 - val_accuracy: 0.5750
# Epoch 6/40
# 16/16 [==============================] - 0s 1ms/step - loss: 1.2001 - accuracy: 0.6390 - val_loss: 1.1853 - val_accuracy: 0.5750
# Epoch 7/40
# 16/16 [==============================] - 0s 1ms/step - loss: 1.1475 - accuracy: 0.6516 - val_loss: 1.1462 - val_accuracy: 0.5750
# Epoch 8/40
# 16/16 [==============================] - 0s 1ms/step - loss: 1.0999 - accuracy: 0.6396 - val_loss: 1.1059 - val_accuracy: 0.5750
# Epoch 9/40
# 16/16 [==============================] - 0s 1ms/step - loss: 1.0809 - accuracy: 0.5902 - val_loss: 1.0666 - val_accuracy: 0.5750
# Epoch 10/40
# 16/16 [==============================] - 0s 1ms/step - loss: 1.0296 - accuracy: 0.6348 - val_loss: 1.0281 - val_accuracy: 0.5750
# Epoch 11/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9863 - accuracy: 0.6442 - val_loss: 0.9906 - val_accuracy: 0.6000
# Epoch 12/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9113 - accuracy: 0.7226 - val_loss: 0.9533 - val_accuracy: 0.6000
# Epoch 13/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.8760 - accuracy: 0.7169 - val_loss: 0.9178 - val_accuracy: 0.6250
# Epoch 14/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.8806 - accuracy: 0.7139 - val_loss: 0.8838 - val_accuracy: 0.6750
# Epoch 15/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.8249 - accuracy: 0.7348 - val_loss: 0.8524 - val_accuracy: 0.7250
# Epoch 16/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.8228 - accuracy: 0.7759 - val_loss: 0.8200 - val_accuracy: 0.7750
# Epoch 17/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.7541 - accuracy: 0.8185 - val_loss: 0.7907 - val_accuracy: 0.8000
# Epoch 18/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.7223 - accuracy: 0.8397 - val_loss: 0.7620 - val_accuracy: 0.8000
# Epoch 19/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6977 - accuracy: 0.8930 - val_loss: 0.7339 - val_accuracy: 0.8500
# Epoch 20/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6731 - accuracy: 0.8906 - val_loss: 0.7060 - val_accuracy: 0.8500
# Epoch 21/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6680 - accuracy: 0.8651 - val_loss: 0.6797 - val_accuracy: 0.8750
# Epoch 22/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6431 - accuracy: 0.9053 - val_loss: 0.6546 - val_accuracy: 0.9250
# Epoch 23/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.5892 - accuracy: 0.9169 - val_loss: 0.6288 - val_accuracy: 0.9000
# Epoch 24/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.5914 - accuracy: 0.9067 - val_loss: 0.6065 - val_accuracy: 0.9500
# Epoch 25/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.5602 - accuracy: 0.9172 - val_loss: 0.5833 - val_accuracy: 0.9500
# Epoch 26/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.8977 - val_loss: 0.5618 - val_accuracy: 0.9500
# Epoch 27/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.4921 - accuracy: 0.9452 - val_loss: 0.5416 - val_accuracy: 0.9500
# Epoch 28/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.5002 - accuracy: 0.9418 - val_loss: 0.5202 - val_accuracy: 0.9500
# Epoch 29/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.5059 - accuracy: 0.9323 - val_loss: 0.5017 - val_accuracy: 0.9500
# Epoch 30/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.4465 - accuracy: 0.9422 - val_loss: 0.4839 - val_accuracy: 0.9500
# Epoch 31/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.4065 - accuracy: 0.9561 - val_loss: 0.4672 - val_accuracy: 0.9500
# Epoch 32/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.4277 - accuracy: 0.9168 - val_loss: 0.4514 - val_accuracy: 0.9500
# Epoch 33/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.3856 - accuracy: 0.9558 - val_loss: 0.4335 - val_accuracy: 0.9500
# Epoch 34/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.3780 - accuracy: 0.9560 - val_loss: 0.4200 - val_accuracy: 0.9500
# Epoch 35/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.3489 - accuracy: 0.9702 - val_loss: 0.4069 - val_accuracy: 0.9500
# Epoch 36/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.3408 - accuracy: 0.9578 - val_loss: 0.3923 - val_accuracy: 0.9500
# Epoch 37/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.3624 - accuracy: 0.9406 - val_loss: 0.3789 - val_accuracy: 0.9500
# Epoch 38/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.3016 - accuracy: 0.9701 - val_loss: 0.3688 - val_accuracy: 0.9500
# Epoch 39/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.3018 - accuracy: 0.9522 - val_loss: 0.3565 - val_accuracy: 0.9500
# Epoch 40/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.3270 - accuracy: 0.9291 - val_loss: 0.3456 - val_accuracy: 0.9500

# %% [markdown]
# Plot the training and validation accuracy.

# %%
err = hist.history['accuracy']
val_err = hist.history['val_accuracy']
epochs = range(1, len(err) + 1)
 
plt.plot(epochs, err, '-', label='Training Accuracy')
plt.plot(epochs, val_err, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %% [markdown]
# Predict class probabilities for a point that lies at (0.2, 0.8).

# %%
model.predict(np.array([[0.2, 0.8]]))[0]
# Out:
# array([2.1869127e-02, 8.9878697e-05, 6.4979903e-02, 9.1306108e-01],
#       dtype=float32)

# %% [markdown]
# Predict which class a point that lies at (0.2, 0.8) belongs to.

# %%
np.argmax(model.predict(np.array([[0.2, 0.8]])), axis=1)[0]
# Out:
# 3

# %% [markdown]
# Predict class probabilities for a point that lies at (0.8, 0.2).

# %%
model.predict(np.array([[0.8, 0.2]]))[0]
# Out:
# array([8.4926672e-02, 9.0637493e-01, 8.5706348e-03, 1.2768240e-04],
#       dtype=float32)

# %% [markdown]
# Predict which class a point that lies at (0.8, 0.2) belongs to.

# %%
np.argmax(model.predict(np.array([[0.8, 0.2]])), axis=1)[0]
# Out:
# 1
